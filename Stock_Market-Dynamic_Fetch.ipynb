# %% [markdown]
# #Stock Market Analysis

# %%
import os
import datetime
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import time
from statistics import mean

now = datetime.datetime.now()
monthinteger=now.month
yr=now.year
yrstr=str(yr)
#print(type(yrstr))
#print("Current year: %d" % now.month)
#print('Current month: ', now.month)
month = datetime.date(1900, monthinteger, 1).strftime('%B')
print(month)
#print(yr)
mnthlist=['January','February','March','April','May','June','July','August','September','October','November','December']
yearlist=['2018','2017','2016','2015','2014','2013','2012','2011','2010','2009','2008']
mnindex=mnthlist.index(month)
yearind=yearlist.index(yrstr)
print(mnindex)
#print(yearind)
#mnth.split("-")
# Out:
# September
# 8

# %%
def styl():
    print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")

# %%
def onem():
   # date1=date[-6:-1]
    datelist=[]
    hpplist=[]
    lpplist=[]
    cpplist=[]
    opplist=[]
    #print(mnthlist[mnindex-1])
    for i in range(len(date[:26])):
        if mnthlist[mnindex-1]in date[i]:
            #date[i]
            datelist.append(date[i])
            hpplist.append(hpp[i])
            lpplist.append(lpp[i])
            cpplist.append(cpp[i])
            opplist.append(opp[i])
            i+=1
        else:
            break
    #print(datelist)
    #print(hpplist)
    #print(max(hpplist))
    plt.figure(figsize=(30,15))
    plt.title('1-Month Analysis(Last Month)',fontsize=28)
    plt.plot(datelist,hpplist,"r",label='High Price')
    plt.plot(datelist,lpplist,"k",label='Low Price')
    plt.plot(datelist,cpplist,"m",label='Close Price')
    plt.plot(datelist,opplist,"c",label='Open Price Price')
    plt.plot(max(hpplist),"or",markersize=15,label='Highest Price %d' %max(hpplist))
    plt.plot(max(lpplist),"vk",markersize=15,label='Lowest price %d' %min(lpplist))
    plt.plot(max(cpplist),"^m",markersize=15,label='Highest Close price %d' %max(cpplist))
    plt.plot(max(opplist),"*c",markersize=15,label='Highest Open price %d' %max(opplist))
    plt.xlabel('Days ->',fontsize=20)
    plt.ylabel('Price ->',fontsize=20)
    plt.legend(loc='upper right',prop={'size': 16})      #Increase legend size
    plt.grid()
    #plt.ylim(min(hpplist),max(hpplist),5)
    plt.yticks(np.arange(min(lpplist),max(hpplist),10))
    plt.xticks(np.arange(0,20,4))
    plt.savefig("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/onem/onemhloc")
    image = Image.open("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/onem/onemhloc.png")
    image.show()
    #plt.show()
   
    watchEQ()

# %%
def twom():
    datelist=[]
    hpplist=[]
    lpplist=[]
    cpplist=[]
    opplist=[]
    #print(mnthlist[mnindex-1])
    for i in range(len(date[:57])):
        if mnthlist[mnindex-1]in date[i] or mnthlist[mnindex-2]in date[i]:
            #date[i]
            datelist.append(date[i])
            hpplist.append(hpp[i])
            lpplist.append(lpp[i])
            cpplist.append(cpp[i])
            opplist.append(opp[i])
            i+=1
        else:
            break
    #print(datelist)
    #print(hpplist)
    #print(max(hpplist))
    plt.figure(figsize=(30,15))
    plt.title('2-Month Analysis',fontsize=28)
    plt.plot(datelist,hpplist,"r",label='High Price')
    plt.plot(datelist,lpplist,"k",label='Low Price')
    plt.plot(datelist,cpplist,"m",label='Close Price')
    plt.plot(datelist,opplist,"c",label='Open Price Price')
    plt.plot(max(hpplist),"or",markersize=15,label='Highest Price %d' %max(hpplist))
    plt.plot(max(lpplist),"vk",markersize=15,label='Lowest price %d' %min(lpplist))
    plt.plot(max(cpplist),"^m",markersize=15,label='Highest Close price %d' %max(cpplist))
    plt.plot(max(opplist),"*c",markersize=15,label='Highest Open price %d' %max(opplist))
    plt.xlabel('Days ->',fontsize=20)
    plt.ylabel('Price ->',fontsize=20)
    plt.legend(loc='upper right',prop={'size': 16})
    plt.grid()
    #plt.ylim(min(hpplist),max(hpplist),5)
    plt.yticks(np.arange(min(lpplist),max(hpplist),10))
    plt.xticks(np.arange(0,len(datelist),4))
    plt.savefig("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/twom/twomhloc")
    image = Image.open("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/twom/twomhloc.png")
    image.show()
    #plt.show()
    watchEQ()

# %%
def sixm():
    datelist=[]
    hpplist=[]
    lpplist=[]
    cpplist=[]
    opplist=[]
    print(mnthlist[mnindex-1])
    #print(mnthlist[mnindex-1])
    for i in range(len(date[:170])):
        if (mnthlist[mnindex-1] in date[i]) or (mnthlist[mnindex-2] in date[i]) or (mnthlist[mnindex-3] in date[i]) or (mnthlist[mnindex - 4] in date[i]) or (mnthlist[mnindex-5] in date[i]) or (mnthlist[mnindex-6] in date[i]):
            #date[i]
            datelist.append(date[i])
            hpplist.append(hpp[i])
            lpplist.append(lpp[i])
            cpplist.append(cpp[i])
            opplist.append(opp[i])
            i+=1
        else:
            break
    #print(datelist)
    #print(hpplist)
    #print(max(hpplist))
    plt.figure(figsize=(40,15))
    plt.title('6-Month Analysis',fontsize=28)
    plt.plot(datelist,hpplist,"r",label='High Price')
    plt.plot(datelist,lpplist,"k",label='Low Price')
    plt.plot(datelist,cpplist,"m",label='Close Price')
    plt.plot(datelist,opplist,"c",label='Open Price Price')
    plt.plot(max(hpplist),"or",markersize=15,label='Highest Price %d' %max(hpplist))
    plt.plot(max(lpplist),"vk",markersize=15,label='Lowest price %d' %min(lpplist))
    plt.plot(max(cpplist),"^m",markersize=15,label='Highest Close price %d' %max(cpplist))
    plt.plot(max(opplist),"*c",markersize=15,label='Highest Open price %d' %max(opplist))
    plt.xlabel('Days ->',fontsize=20)
    plt.ylabel('Price ->',fontsize=20)
    plt.legend(loc='upper right',prop={'size': 16})
    plt.grid()
    #plt.ylim(min(hpplist),max(hpplist),5)
    plt.yticks(np.arange(min(lpplist),max(hpplist),10))
    plt.xticks(np.arange(0,len(datelist),15))
    plt.savefig("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/sixm/sixmhloc")
    image = Image.open("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/sixm/sixmhloc.png")
    image.show()
    #plt.show()
    watchEQ()

# %%
def oney():
    yrlist=[]
    hpplist=[]
    lpplist=[]
    cpplist=[]
    opplist=[]
    #print(yearlist[yearind])
    for i in range(len(date[:340])):
        if yearlist[yearind] in date[i]:
            #date[i]
            yrlist.append(date[i])
            hpplist.append(hpp[i])
            lpplist.append(lpp[i])
            cpplist.append(cpp[i])
            opplist.append(opp[i])
            i+=1
        else:
            break
    #print(yrlist)
    plt.figure(figsize=(40,15))
    plt.title('1-Year Analysis',fontsize=28)
    plt.plot(yrlist,hpplist,"r",label='High Price')
    plt.plot(yrlist,lpplist,"k",label='Low Price')
    plt.plot(yrlist,cpplist,"m",label='Close Price')
    plt.plot(yrlist,opplist,"c",label='Open Price Price')
    plt.plot(max(hpplist),"or",markersize=15,label='Highest Price %d' %max(hpplist))
    plt.plot(max(lpplist),"vk",markersize=15,label='Lowest price %d' %min(lpplist))
    plt.plot(max(cpplist),"^m",markersize=15,label='Highest Close price %d' %max(cpplist))
    plt.plot(max(opplist),"*c",markersize=15,label='Highest Open price %d' %max(opplist))
    plt.xlabel('Days ->',fontsize=20)
    plt.ylabel('Price ->',fontsize=20)
    plt.legend(loc='upper right',prop={'size': 16})
    plt.grid()
    #plt.ylim(min(hpplist),max(hpplist),5)
    plt.yticks(np.arange(min(lpplist),max(hpplist),10))
    plt.xticks(np.arange(0,len(yrlist),10))
    plt.savefig("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/oney/oneyhloc")
    image = Image.open("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/oney/oneyhloc.png")
    image.show()
    #plt.show()
    watchEQ()

# %%
def twoy():
    yrlist=[]
    hpplist=[]
    lpplist=[]
    cpplist=[]
    opplist=[]
    #print(yearlist[yearind])
    for i in range(len(date[:750])):
        if yearlist[yearind] in date[i]:
            #date[i]
            yrlist.append(date[i])
            hpplist.append(hpp[i])
            lpplist.append(lpp[i])
            cpplist.append(cpp[i])
            opplist.append(opp[i])
            i+=1
        else:
            break
    #print(yrlist)
    plt.figure(figsize=(40,15))
    plt.title('2-Year Analysis',fontsize=28)
    plt.plot(yrlist,hpplist,"r",label='High Price')
    plt.plot(yrlist,lpplist,"k",label='Low Price')
    plt.plot(yrlist,cpplist,"m",label='Close Price')
    plt.plot(yrlist,opplist,"c",label='Open Price Price')
    plt.plot(max(hpplist),"or",markersize=15,label='Highest Price %d' %max(hpplist))
    plt.plot(max(lpplist),"vk",markersize=15,label='Lowest price %d' %min(lpplist))
    plt.plot(max(cpplist),"^m",markersize=15,label='Highest Close price %d' %max(cpplist))
    plt.plot(max(opplist),"*c",markersize=15,label='Highest Open price %d' %max(opplist))
    plt.xlabel('Days ->',fontsize=20)
    plt.ylabel('Price ->',fontsize=20)
    plt.legend(loc='upper right',prop={'size': 16})
    plt.grid()
    #plt.ylim(min(hpplist),max(hpplist),5)
    plt.yticks(np.arange(min(lpplist),max(hpplist),10))
    plt.xticks(np.arange(0,len(yrlist),13))
    plt.savefig("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/twoy/twoyhloc")
    image = Image.open("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/twoy/twoyhloc.png")
    image.show()
    #plt.show()
    watchEQ()

# %%
def fivy():
    yrlist=[]
    hpplist=[]
    lpplist=[]
    cpplist=[]
    opplist=[]
    #print(yearlist[yearind])
    for i in range(len(date[:1300])):
        if yearlist[yearind] in date[i]:
            #date[i]
            yrlist.append(date[i])
            hpplist.append(hpp[i])
            lpplist.append(lpp[i])
            cpplist.append(cpp[i])
            opplist.append(opp[i])
            i+=1
        else:
            break
    #print(yrlist)
    plt.figure(figsize=(40,15))
    plt.title('5-Year Analysis',fontsize=28)
    plt.plot(yrlist,hpplist,"r",label='High Price')
    plt.plot(yrlist,lpplist,"k",label='Low Price')
    plt.plot(yrlist,cpplist,"m",label='Close Price')
    plt.plot(yrlist,opplist,"c",label='Open Price Price')
    plt.plot(max(hpplist),"or",markersize=15,label='Highest Price %d' %max(hpplist))
    plt.plot(max(lpplist),"vk",markersize=15,label='Lowest price %d' %min(lpplist))
    plt.plot(max(cpplist),"^m",markersize=15,label='Highest Close price %d' %max(cpplist))
    plt.plot(max(opplist),"*c",markersize=15,label='Highest Open price %d' %max(opplist))
    plt.xlabel('Days ->',fontsize=20)
    plt.ylabel('Price ->',fontsize=20)
    plt.legend(loc='upper right',prop={'size': 16})
    plt.grid()
    #plt.ylim(min(hpplist),max(hpplist),5)
    plt.yticks(np.arange(min(lpplist),max(hpplist),10))
    plt.xticks(np.arange(0,len(yrlist),17))
    plt.savefig("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/fivy/fivyhloc")
    image = Image.open("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/fivy/fivyhloc.png")
    image.show()
    #plt.show()
    watchEQ()

# %%
def teny():
    yrlist=[]
    hpplist=[]
    lpplist=[]
    cpplist=[]
    opplist=[]
    #print(yearlist[yearind])
    for i in range(len(date[:2642])):
        if yearlist[yearind] in date[i]:
            #date[i]
            yrlist.append(date[i])
            hpplist.append(hpp[i])
            lpplist.append(lpp[i])
            cpplist.append(cpp[i])
            opplist.append(opp[i])
            i+=1
        else:
            break
    #print(yrlist)
    plt.figure(figsize=(40,15))
    plt.title('5-Year Analysis',fontsize=28)
    plt.plot(yrlist,hpplist,"r",label='High Price')
    plt.plot(yrlist,lpplist,"k",label='Low Price')
    plt.plot(yrlist,cpplist,"m",label='Close Price')
    plt.plot(yrlist,opplist,"c",label='Open Price Price')
    plt.plot(max(hpplist),"or",markersize=15,label='Highest Price %d' %max(hpplist))
    plt.plot(max(lpplist),"vk",markersize=15,label='Lowest price %d' %min(lpplist))
    plt.plot(max(cpplist),"^m",markersize=15,label='Highest Close price %d' %max(cpplist))
    plt.plot(max(opplist),"*c",markersize=15,label='Highest Open price %d' %max(opplist))
    plt.xlabel('Days ->',fontsize=20)
    plt.ylabel('Price ->',fontsize=20)
    plt.legend(loc='upper right',prop={'size': 16})
    plt.grid()
    #plt.ylim(min(hpplist),max(hpplist),5)
    plt.yticks(np.arange(min(lpplist),max(hpplist),10))
    plt.xticks(np.arange(0,len(yrlist),20))
    plt.savefig("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/teny/tenyhloc")
    image = Image.open("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/teny/tenyhloc.png")
    image.show()
    #plt.show()
    watchEQ()

# %%
def watchEQ():
    #print("watch")
    chw=input("Watch Market....Proceed(y/Y or n/N)?: ")
    while(chw=='y' or chw=='Y'):
        print("1. 1-Month\n2. 2-Month\n3. 6-Month\n4. 1=Year\n5. 2-Year\n6. 5-Year\n7. 10-Year")
        chw=int(input(":"))
        if chw==1:
            onem()
        elif chw==2:
            twom()
        elif chw==3:
            sixm()
        elif chw==4:
            oney()
        elif chw==5:
            twoy()
        elif chw==6:
            fivy()
        elif chw==7:
            teny()
        chw=input("Continue watching Equity(y/Y or n/N)?: ")
    servc()

# %%
def buyEQ():
    #print("buy")
    styl()
    print("In my view, take advice first to buy Equity....")
    styl()
    time.sleep(2)
    print("While taking Advice, you will be more familier to Market Strategy\nHi-Lo, Open-Close,Volume of Equity....")
    styl()
    time.sleep(2)
    chb=input("To proceed ADVICE section, Press 'y/Y' otherwise press 'n/N'")
    if chb=='y' or chb=='Y':
        advice()
    elif chb=='n' or chb=='N':
        print("Buy")
    servc()

# %%
def predval():
    hp=eqdata['High Price'].tolist()
    op=eqdata['Open Price'].tolist()
    cp=eqdata['Close Price'].tolist()
    lp=eqdata['Low Price'].tolist()
    date=eqdata['Date'].tolist()
    ns=eqdata['No.of Shares'].tolist()
    nt=eqdata['No. of Trades'].tolist()
    tt=eqdata['Total Turnover (Rs.)'].tolist()
    ho=[]
    hc=[]
    trdiff=[]
    shrdiff=[]
    runavglist=[]
    primepredict=[]
    for i in range(len(hp)-1):
        x=hp[i]-op[i]
        ho.append(x)                               #Difference of High-Low
        
        x=(hp[i]+op[i]+cp[i]+lp[i])/4
        runavglist.append(x)                       #Running Average List of High-Low-Close-Open
        
        x=hp[i]-cp[i]
        hc.append(x)                               #Difference of High-Close             
        
        x=nt[i]-nt[i+1]
        trdiff.append(x)                           #Trade Breakeoff or Difference
        
        x=ns[i]-ns[i+1]
        shrdiff.append(x)                          #Share Breakeoff or Difference   
        
    runavg1m=sum(runavglist[:26])/26
    runavg2m=sum(runavglist[:57])/57
    runavg6m=sum(runavglist[:170])/170
    runavg1y=sum(runavglist[:340])/340
    runavg2y=sum(runavglist[:680])/680
    runavg5y=sum(runavglist[:1300])/1300
    runavg10y=sum(runavglist[:2642])/2642
    
    plt.plot(runavg1y)

    #print(len(hp))
    l1=[]
    for i in range(len(hp)-1):
        x=hp[i]-op[i]
        l1.append(x)
        #y=(hp[i]+op[i]+cp[i]+lp[i])/4
        #l2.append(y)
    #runavg1m=(sum(l2[:31])/31)/4
    #runavg2m=(sum(l2[:63])/63)/4
    #avg1=sum(l1[:31])/len(l1[:31])
    #avg2=sum(l1[:63])/len(l1[:63])
    #nos=file['No.of Shares'].tolist()
    #ntr=file['No. of Trades'].tolist()
    
    pp=[]
    for i in range(len(hp)-1):
        x=tt[i]/ns[i]
        pp.append(x)
    import random
    slope=[]
    for i in range(len(runavglist)):
        m=runavglist[i]/pp[i]
        slope.append(m)
    pred=[]
    hln=len(hp)
    for i in range(len(hp)-1):
        a1=(hp[i]+op[i])/2
        a2=(hp[i]+lp[i])/2
        y=random.uniform(float(a1),float(a2))
        pred.append(y*slope[:hln][i])
    #plt.plot(pred)
    return pred,runavg1m,runavg2m,runavg6m,runavg1y,cp
    #return cp,pred

# %%
def adEQ():
    pred,run1m,run2m,run6m,run1y,cp=predval()
    ch=int(input("Prediction for ?\n1. For Next Day\n2. For Next Month\n3. For next 6 Month\n4. For Next 1 Year"))
    if ch==1:
        if cp[0]<pred[0]:
            print("Trending price for tomorrow")
            print("Compared to previous Stock Price: ",((cp[1]-cp[0])/cp[1])*100,"%")
            print("Last outstanding Stock Price: ",cp[0])
            print("Probable Stock price: ",pred[0])
            print("UP",((pred[0]-cp[0])/cp[0])*100,"%")
            print("You can sell it tomorrow....")
        elif cp[0]>pred[0]:
            print("Trending price for tomorrow")
            print("Compared to previous Stock Price: ",((cp[1]-cp[0])/cp[1])*100,"%")
            print("Last outstanding Stock Price: ",cp[0])
            print("Probable Stock price: ",pred[0])
            if pred[0]>cp[0]:
                print("UP",((cp[0]-pred[0])/cp[0])*100,"%")
            print("You can buy it tomorrow....")
    elif ch==2:
            print("Trending Maximum Price(1-Month Prediction): ",max(pred[:26]))
            plt.figure(figsize=(40,15))
            plt.title('1-Month Prediction',fontsize=28)
            plt.plot(pred[:26],"r",label="Trending Price curve")
            #plt.plot(max(hpplist),"ok",markersize=15,label='Highest Price %d' %max(pred[:26]))
            plt.hlines(run1m,0,31,"m")
            plt.xticks(np.arange(0,len(pred[:26]),2))
            plt.yticks(np.arange(min(pred[:26]),max(pred[:26]),10))
            plt.legend(loc='upper right',prop={'size': 16})
            plt.grid()
            plt.savefig("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/onrmpred")
            image = Image.open("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/onrmpred.png")
            image.show()   
    elif ch==3:
            print("Trending Maximum Price(1-Month Prediction): ",max(pred[:170]))
            plt.figure(figsize=(40,15))
            plt.title('6-Month Prediction',fontsize=28)
            plt.plot(pred[:26],"r",label="Trending Price curve")
            #plt.plot(max(hpplist),"ok",markersize=15,label='Highest Price %d' %max(pred[:170]))
            plt.hlines(run6m,0,31,"m")
            plt.xticks(np.arange(0,len(pred[:26]),2))
            plt.yticks(np.arange(min(pred[:170]),max(pred[:170]),10))
            plt.legend(loc='upper right',prop={'size': 16})
            plt.grid()
            plt.savefig("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/sixmpred")
            image = Image.open("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Analysis/sixmpred.png")
            image.show()

# %%
def advice():
    styl()
    print("Welcome to Advice section")
    styl()
    time.sleep(2)
    print("Choose one from the following: ")
    print("1. Watch Analysis Report")
    print("2. Advice for selling/purchasing Equity")
    cha=int(input("Enter your Choice: "))
    if cha==1:
        watchEQ()
    elif cha==2:
        adEQ()
    return

# %%
def servc():
    styl()
    ch=input("To Proceed Service, Type 'y/Y': ")
    styl()
    if ch=='y' or ch=='Y':
        print("List of Services:\n1. Watch Equity\n2. Buy Equity\n3. Advise")
        cho=int(input("Enter your choice: "))
        styl()
        #servc(cho)
        if cho==1:
            watchEQ()
        elif cho==2:
            buyEQ()
        elif cho==3:
            advice() 
    return

# %%
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~Welcome to XXYY Consultancy~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n\tWe provide Real Time Market watch and Stock Prediction of Inter Day or IntraDay\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
print("Currently we are providing service for:\n")
servlist=os.listdir("C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/ServiceData")
for i in range(len(servlist)):
    print(i+1,".",servlist[i])
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~Welcome to XXYY Consultancy~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 	We provide Real Time Market watch and Stock Prediction of Inter Day or IntraDay
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Currently we are providing service for:
#
# 1 . AXIS
# 2 . LIC
# 3 . reliencecomm
# 4 . SBI
# 5 . tatasteel
# 6 . TCS
# 7 . Wipro

# %%
path="C:/Users/Subhadeep Chakrabort/Desktop/Stock Market/Datafile/"
datalist=os.listdir(path)
styl()
ch=int(input("Enter a Equity to get in Service:(eg.1,2 etc.): "))
styl()
if ch<=0 or ch>7:
    print("Not a Valid Selection")
else:   
    print("You have selected: ",servlist[ch-1])

#Dataset for Analysis
eqdata=pd.read_csv(path+datalist[ch-1])     #Fetch CSV dynamically, irrespective of no. of files
#datamod(eqdata)          #Sens data to drom unnecessarry columns
date=eqdata['Date'].tolist()
#print(date)
opp=eqdata['Open Price'].tolist()

hpp=eqdata['High Price'].tolist()
lpp=eqdata['Low Price'].tolist()

cpp=eqdata['Close Price'].tolist()

nos=eqdata['No.of Shares'].tolist()
ntr=eqdata['No. of Trades'].tolist()
tt=eqdata['Total Turnover (Rs.)'].tolist()
#print(opp)

servc()
exit(0)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
